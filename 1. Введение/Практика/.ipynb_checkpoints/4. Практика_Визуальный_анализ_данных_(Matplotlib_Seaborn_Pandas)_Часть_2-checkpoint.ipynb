# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandre77777/data_mining/blob/main/1.%20%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0/4.%20%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_(Matplotlib_Seaborn_Pandas)_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практика. Визуальный анализ данных (Matplotlib/Seaborn/Pandas). Часть 2
#
#
# 1. Скачайте этот блокнот к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём репозитории.
#
# #### Полезная литература
# - [**Блокнот с теорией**](https://colab.research.google.com/github/Alexandre77777/data_mining/blob/main/1.%20%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5/%D0%A2%D0%B5%D0%BE%D1%80%D0%B8%D1%8F/3.%20%D0%A2%D0%B5%D0%BE%D1%80%D0%B8%D1%8F_Matplotlib_Seaborn_Plotly.ipynb)
# - [Галерея графиков Matplotlib](https://matplotlib.org/gallery/index.html)
# - [Галерея графиков Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Открытый курс машинного обучения. Тема 2: Визуализация данных c Python](https://habr.com/company/ods/blog/323210/)

# %%
 # !pip install seaborn==0.11.0
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#                                               0.0/283.1 kB ? eta -:--:--
#      -                                        10.2/283.1 kB ? eta -:--:--
#      -                                        10.2/283.1 kB ? eta -:--:--
#      -----                                 41.0/283.1 kB 326.8 kB/s eta 0:00:01
#      ------------                          92.2/283.1 kB 585.1 kB/s eta 0:00:01
#      --------------                       112.6/283.1 kB 547.6 kB/s eta 0:00:01
#      ------------------                   143.4/283.1 kB 568.9 kB/s eta 0:00:01
#      ----------------------               174.1/283.1 kB 618.3 kB/s eta 0:00:01
#      ----------------------------         225.3/283.1 kB 655.6 kB/s eta 0:00:01
#      --------------------------------     256.0/283.1 kB 714.4 kB/s eta 0:00:01
#      ------------------------------------ 283.1/283.1 kB 672.1 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from seaborn==0.11.0) (1.25.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from seaborn==0.11.0) (1.11.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from seaborn==0.11.0) (2.0.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from seaborn==0.11.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from matplotlib>=2.2->seaborn==0.11.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from pandas>=0.23->seaborn==0.11.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from pandas>=0.23->seaborn==0.11.0) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.0) (1.16.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed seaborn-0.11.0

# %% [markdown]
# ## Визуальный анализ данных
#
# В этом задании вам предлагается провести визуальный анализ датасета результатов экзаменов студентов  https://www.kaggle.com/spscientist/students-performance-in-exams.

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Задания
# #### 1. Постройте 3 графика, показывающих распределение результатов экзаменов (каждый график на предмет).
#
#
# Графики должны быть в одном ряду и у них должен быть общий заголовок "Результаты экзаменов".
#
# Для результатов каждого экзамена посчитайте медианные значения.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

subjects = ['math score', 'reading score', 'writing score']

colors = ['skyblue', 'lightcoral', 'lightgreen']

for i, subject in enumerate(subjects):
    ax = axes[i]
    ax.hist(df[subject], bins=20, color=colors[i])
    ax.set_title(subject)
    ax.set_xlabel('Score')
    ax.set_ylabel('Frequency')

plt.suptitle('Результаты экзаменов', fontsize=16)

plt.show()

# %%
math_median = df['math score'].median()
reading_median = df['reading score'].median()
writing_median = df['writing score'].median()

print(f"Медианное значение по математике: {math_median}")
print(f"Медианное значение по чтению: {reading_median}")
print(f"Медианное значение по письму: {writing_median}")
# Out:
# Медианное значение по математике: 66.0
# Медианное значение по чтению: 70.0
# Медианное значение по письму: 69.0

# %% [markdown]
# #### 2. Образование родителей
# Какие уровни образование есть в столбце *'parental level of education'* и сколько строк в датафрейме соответствует каждому уровню?
#
# Постройте график и ответьте на вопрос ниже
#
# Отличаются ли баллы по математике у детей с разным образованием родителей?
# Постройте график, где по оси Х находятся уровни образования родителей, а по У - баллы по математике.

# %%
education_levels = df['parental level of education'].unique()

education_counts = {}

for level in education_levels:
    count = df[df['parental level of education'] == level].shape[0]
    education_counts[level] = count

plt.figure(figsize=(10, 6))
plt.bar(education_counts.keys(), education_counts.values())
plt.xlabel('Уровень образования родителей')
plt.ylabel('Количество студентов')
plt.title('Количество студентов по уровню образования родителей')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(df['parental level of education'], df['math score'])
plt.xlabel('Уровень образования родителей')
plt.ylabel('Баллы по математике')
plt.title('Баллы по математике в зависимости от образования родителей')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 3. Выведите число студенток, набравших больше 90 баллов по всем предметам.

# %%
filtered_df = df[(df['math score'] > 90) & (df['reading score'] > 90) & (df['writing score'] > 90) & (df['gender'] == 'female')]
len(filtered_df)
# Out:
# 17

# %% [markdown]
# #### 4. Сравните баллы у студентов разных полов. Используя agg() выведите минимальное, максимальное и медианное значение

# %%
result = df.groupby('gender').agg({'math score': ['min', 'max', 'median'], 'reading score': ['min', 'max', 'median'], 'writing score': ['min', 'max', 'median']})
result
# Out:
#        math score             reading score             writing score       \
#               min  max median           min  max median           min  max
# gender
# female          0  100   65.0            17  100   73.0            10  100
# male           27  100   69.0            23  100   66.0            15  100
#
#
#        median
# gender
# female   74.0
# male     64.0

# %% [markdown]
# #### 5. Выясните, влияет ли обед и подготовка к тесту на средний балл студентов разного пола
# ###### (подсказка: используете agg())

# %%
result = df.groupby(['gender', 'lunch', 'test preparation course']).agg({
    'math score': 'mean',
    'reading score': 'mean',
    'writing score': 'mean'
})

result
# Out:
#                                              math score  reading score  \
# gender lunch        test preparation course
# female free/reduced completed                 60.785714      73.428571
#                     none                      52.890756      63.831933
#        standard     completed                 71.131579      79.798246
#                     none                      66.530233      73.386047
# male   free/reduced completed                 65.639344      65.786885
#                     none                      60.609524      59.076190
#        standard     completed                 75.955752      72.601770
#                     none                      69.832512      64.719212
#
#                                              writing score
# gender lunch        test preparation course
# female free/reduced completed                    74.371429
#                     none                         61.781513
#        standard     completed                    81.508772
#                     none                         72.967442
# male   free/reduced completed                    65.737705
#                     none                         55.285714
#        standard     completed                    71.982301
#                     none                         61.906404

# %% [markdown]
# #### 6. Постройте график, показывающий зависимость уровня образования родителей от их расы

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='parental level of education', hue='race/ethnicity')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Уровень образования родителей")
plt.ylabel("Количество")
plt.title("Зависимость уровня образования родителей от их расы")

plt.legend(title='Раса/этническая группа', loc='upper right')

plt.show()

# %% [markdown]
# #### 7. Постройте график, показывающий зависимость прохождения подготовительного теста от уровня образования родителей.
#
#
# Кто чаще ходит на курсы: дети, родители которых закончили только старшую школу, или дети, чьи родители получили степень бакалавра\магистра?

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='parental level of education', hue='test preparation course')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Уровень образования родителей")
plt.ylabel("Количество")
plt.title("Зависимость прохождения подготовительного теста от уровня образования родителей")

plt.legend(title='Прохождение подготовительного теста', loc='upper right')

plt.show()

# %% [markdown]
# #### 8. Постройте plot.pie, показывающий, сколько людей сдали\не сдали экзамен по математике.
#
# Сдавшим считается человек, набравший 40 баллов.
#
# ###### Подсказка: создайте столбец в датафрейме, который содержит результат сдачи (сдал или не сдал)

# %%
df['pass_math_exam'] = df['math score'] >= 40

pass_count = df['pass_math_exam'].sum()
fail_count = len(df) - pass_count

counts = [pass_count, fail_count]
labels = ['Сдал', 'Не сдал']

plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Сдача экзамена по математике")

plt.show()

# %% [markdown]
# #### 9. Постройте plot.pie, показывающий распределение студентов по оценкам
#
# Оценки студентов выставляются по шкале:<br>
# 0  - 40 marks : grade E<br>
# 41 - 60 marks : grade D<br>
# 60 - 70 marks : grade C<br>
# 70 - 80 marks : grade B<br>
# 80 - 90 marks : grade A<br>
# 90 - 100 marks : grade O<br>
#
# Для этого посчитайте сумму результатов за 3 экзамена и найдите среднее. Оценка выставляется по среднему значению. Если студент не сдал математику(даже если средний балл выше 40), он получает Е

# %%
df['average_score'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)

# Функция для определения оценки на основе среднего балла
def get_grade(average_score):
    if average_score < 40:
        return 'E'
    elif 40 <= average_score < 60:
        return 'D'
    elif 60 <= average_score < 70:
        return 'C'
    elif 70 <= average_score < 80:
        return 'B'
    elif 80 <= average_score < 90:
        return 'A'
    else:
        return 'O'

df['grade'] = df['average_score'].apply(get_grade)

grade_counts = df['grade'].value_counts()

labels = grade_counts.index
counts = grade_counts.values

plt.figure(figsize=(6, 6))
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Распределение студентов по оценкам")

plt.show()

# %% [markdown]
# #### 10. Постройте countplot, показывающий зависимость между итоговой оценкой студентов и его полом. Студенты какого пола получили больше оценок О, А, В

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='grade', hue='gender', order=['O', 'A', 'B', 'C', 'D', 'E'], palette='Set2')
plt.title("Зависимость между итоговой оценкой и полом студентов")
plt.xlabel("Итоговая оценка")
plt.ylabel("Количество студентов")

plt.show()
